# %% [markdown]
# <a href="https://colab.research.google.com/github/longbui23/Amazon-Sentiment-Analysis/blob/main/GeneralAnalysisAndDataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AMAZON SENTIMENT ANALYSIS ON PHONE PAYMENTS**

# %% [markdown]
#   <a id="top"></a>
#     <div class="list-group" id="list-tab" role="tablist">
#     <h1 class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home">Table of Content</h1>
#
# * [1. Dataset and Libraries](#1)
#   - [a. Import Libraries and Dataset](#1a)
#   - [b. Data Inspection](#1b)
# * [2. Data Cleaning](#2)
#   - [a. Brand Names](#2a)
#   - [b. Reviews & Rating](#2b)
#   - [a. Price](#2c)
# * [3. Data Visualization](#3)
# * [4. Data Export](#4)
# * [5. Sentiment Analysis](#5)

# %% [markdown]
# <a id="1"></a>
# <font color="blue" size=+2.5><b>1. Datasets and Libraries</b></font>

# %% [markdown]
# <a id="1a"></a>
# <font color="black" size=+1.5><b>a. Import Dataset and Library</b></font>

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/ECON314: Amazon-Sentiment-Analysis
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/ECON314: Amazon-Sentiment-Analysis

# %%
#import packages
#data cleaning
import numpy as np
import pandas as pd
import statsmodels

#data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import data
df = pd.read_csv("Data/Amazon_Unlocked_Mobile.csv")
df.head()
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %% [markdown]
# <a id="1b"></a>
# <font color="black" size=+1.5><b>b. Data Inspection </b></font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413840 entries, 0 to 413839
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Product Name  413840 non-null  object
#  1   Brand Name    348669 non-null  object
#  2   Price         407907 non-null  float64
#  3   Rating        413840 non-null  int64
#  4   Reviews       413778 non-null  object
#  5   Review Votes  401544 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 18.9+ MB

# %%
df.isnull().sum()
# Out:
# Product Name        0
# Brand Name      65171
# Price            5933
# Rating              0
# Reviews            62
# Review Votes    12296
# dtype: int64

# %% [markdown]
# We could obeserve that the dataset includes numerous missing values in Brand Name, Price, Reviews, and Review Votes columns which we would later inspect and attempt to replace these empty with reasonable assessment.

# %%
df.describe()
# Out:
#                Price         Rating   Review Votes
# count  407907.000000  413840.000000  401544.000000
# mean      226.867155       3.819578       1.507237
# std       273.006259       1.548216       9.163853
# min         1.730000       1.000000       0.000000
# 25%        79.990000       3.000000       0.000000
# 50%       144.710000       5.000000       0.000000
# 75%       269.990000       5.000000       1.000000
# max      2598.000000       5.000000     645.000000

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

sns.distplot(df['Price'], ax=axes[0])
axes[0].set_title('Price Distribution')

sns.boxplot(np.log(df[df['Review Votes'] > 0]['Review Votes']), ax=axes[1])
axes[1].set_title('Log of Review Votes Distribution')

sns.boxplot(df['Rating'], ax=axes[2])
axes[2].set_title('Rating Distribution')

plt.show()
# Out:
# <ipython-input-9-9d0eb30d3ed6>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'], ax=axes[0])

# %% [markdown]
# According to the graph above, price of phones consists a dominant range from $100 to $700 and there are a groups of phone price around $2000.
#
# Most comments have an average of 0 to 300 review votes while some are distinguishingly high.
#
# Most of the ratings are from 3 to 5, indicating that products in the dataset has high level of satisfaction from buyers.

# %% [markdown]
# ## Price

# %%
top_product = df[df['Price']>=2000].sort_values(by='Price', ascending=False)
top_product['Edition'] = top_product['Product Name'].str.split().str[-1]
top_product[['Product Name','Edition']][1:]
# Out:
#                                              Product Name  Edition
# 209686  Lenovo VIBE X2 3G Unlocked Smartphone 5.0 inch...   (Gold)
# 209687  Lenovo VIBE X2 3G Unlocked Smartphone 5.0 inch...   (Gold)
# 209689  Lenovo VIBE X2 3G Unlocked Smartphone 5.0 inch...   (Gold)
# 209688  Lenovo VIBE X2 3G Unlocked Smartphone 5.0 inch...   (Gold)
# 306411  Samsung Galaxy A5 A500M 16GB Unlocked GSM 4G L...  (Black)
# ...                                                   ...      ...
# 136243  BLU Studio 5.0 C HD Smartphone - Unlocked - Ye...   Yellow
# 136242  BLU Studio 5.0 C HD Smartphone - Unlocked - Ye...   Yellow
# 136241  BLU Studio 5.0 C HD Smartphone - Unlocked - Ye...   Yellow
# 136240  BLU Studio 5.0 C HD Smartphone - Unlocked - Ye...   Yellow
# 404002  Unlocked Lenovo Note 8 A936 6 inch IPS Capacit...    Card)
#
# [5245 rows x 2 columns]

# %% [markdown]
# <u>Most expensive:</u> Sattelite phone --> enable to call, message, and data service everywhere on Earth + Rating maximum --> That's why it is so expensive.
#
# <u>Other expensive phones</u>: Limited Edition, Gold Edition

# %%
affd_prod = df[df['Price']==df['Price'].min()]
affd_prod['Edition'] = affd_prod['Product Name'].str.split().str[-1]
affd_prod
# Out:
# <ipython-input-11-362f47619593>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   affd_prod['Edition'] = affd_prod['Product Name'].str.split().str[-1]
#                                              Product Name Brand Name  Price  \
# 205718  Iphone 5 & 5S Replacement Belt Clip for OtterB...   OtterBox   1.73
# 205719  Iphone 5 & 5S Replacement Belt Clip for OtterB...   OtterBox   1.73
# 205720  Iphone 5 & 5S Replacement Belt Clip for OtterB...   OtterBox   1.73
# 205721  Iphone 5 & 5S Replacement Belt Clip for OtterB...   OtterBox   1.73
# 205722  Iphone 5 & 5S Replacement Belt Clip for OtterB...   OtterBox   1.73
# ...                                                   ...        ...    ...
# 206163  Iphone 5 & 5S Replacement Belt Clip for OtterB...   OtterBox   1.73
# 206164  Iphone 5 & 5S Replacement Belt Clip for OtterB...   OtterBox   1.73
# 206165  Iphone 5 & 5S Replacement Belt Clip for OtterB...   OtterBox   1.73
# 206166  Iphone 5 & 5S Replacement Belt Clip for OtterB...   OtterBox   1.73
# 206167  Iphone 5 & 5S Replacement Belt Clip for OtterB...   OtterBox   1.73
#
#         Rating                                            Reviews  \
# 205718       3                        Got this for some one else,
# 205719       1                                          Its cheap
# 205720       5  good product, took an extra long time to get b...
# 205721       5                            Works like the original
# 205722       3  It's ok but not same quality as Otto. The clip...
# ...        ...                                                ...
# 206163       5  Awesome cheap replacement for otterbox clip th...
# 206164       5             Nice product. It came on time. Thanks.
# 206165       1       Did not hold my phone...not a good product!!
# 206166       3         Worked ok could have been a little tighter
# 206167       2  Cheap quality and is not up to par like real o...
#
#         Review Votes Edition
# 205718           0.0   Cases
# 205719           0.0   Cases
# 205720           0.0   Cases
# 205721           0.0   Cases
# 205722           0.0   Cases
# ...              ...     ...
# 206163           0.0   Cases
# 206164           0.0   Cases
# 206165           0.0   Cases
# 206166           0.0   Cases
# 206167           0.0   Cases
#
# [450 rows x 7 columns]

# %%
affd_prod = df[df['Price']<=5].sort_values(by='Price', ascending=False)
affd_prod['Edition'] = affd_prod['Product Name'].str.split().str[-1]
affd_prod['Edition'].value_counts()
# Out:
# Cases      450
# Unused     198
# SIM         44
# Black       14
# Service      5
# Fast         1
# Name: Edition, dtype: int64

# %% [markdown]
# Should drop all values that has cases, Sims, or Services

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <ipython-input-13-c1a82a4801f0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# Skew to the right --> log --> central skew (normal distribution) --> easier to run regression or comparision

# %% [markdown]
# ## Review Votes

# %%
print(df['Review Votes'].max())
df[df['Review Votes'] == df['Review Votes'].max()]['Reviews'].value_counts()
# Out:
# 645.0
# Hello !!I am writing this review so maybe I can help someone not waste 600 bucks on this deal.Bought this phone 2 months ago and shipped it inside the US.You might initially think this phone is sold by Samsung as Amazon states on the seller name. Well, it is not. It is really sold by a company called Worldwide Distributors.The model that this company shipped me is originally built to be used in Africa so the charging cube isnt useful with US power outlets; had to buy an original in the US to get started with it.This model will work almost with any US operator or at least mine worked with AT&T, Verizon, Telcel (Mexico), Claro (Argentina, Colombia).The issue I am having with this phone is that after 3 weeks of normal use, the display stopped working, the screen will go blank and it will remain unusable for maybe an hour. After this time period the display will come up but all tinted pink, that lasted for an hour and then the display will go blank again. This cycle repeated every day so you may imagine how frustrated I got with this hardware issue. After getting my old iphone 5 up again, I took the phone to a Samsung service shop and they refused to honor the warranty arguing that this product was not purchased through an authorized Samsung reseller and they can't even be sure that it wasnt a stolen one. After a month and 5 days I issued a return request to Amazon explaining the challenges I was facing with the product and the warranty claim. Amazon forwarded this return request to Worldwide Distributors and they answered the claim: "Dear BuyerYour unit has a 1 yr warranty through the manufacturer. Please contact them for further assistance. Samsung Contact: [...]"I responded that I have already taken the phone to an authorized Samsung repair shop to honor the warranty and they refused to service my unit.Since then I havent had any news from Worldwide Distributors or Amazon, so I'm stuck with a 600 usd unusable phone and really frustrated with this company's customer service.Hope this helps !!!    1
# Name: Reviews, dtype: int64

# %% [markdown]
# Looks like the review that has the highest review votes is a complaint vote.

# %%
sns.displot(np.log(df['Reviews'].str.len()))
plt.title("Log Reviews Length")
# Out:
# Text(0.5, 1.0, 'Log Reviews Length')

# %% [markdown]
# ## Rating

# %%
#Plot style
fig, axes = plt.subplots(1, 2, figsize=(15, 8))
sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})

# Brand distribution
brand_df = df.groupby("Brand Name").agg({'Brand Name':'count','Rating':'mean'}).rename(
    columns={"Brand Name": "Count"}).sort_values(by='Count',ascending=False).head(10)

#pie-plot for number of phones ordered by brand
axes[0].pie(
    data=brand_df,
    x = 'Count',
    labels=brand_df.index,
    autopct = '%1.0f%%',
    textprops = {'fontsize':11},
    colors= sns.color_palette("Spectral"),
    explode=[0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,]
)
axes[0].set_title('Top 10 biggest brand by number of phones')

#bar-plot for top 10 biggest brand
axes[1] = sns.barplot(
    data=brand_df.sort_values('Rating', ascending=False),
    x='Rating',
    y=brand_df.index,

    palette = sns.color_palette("husl"),
)
axes[1].set_title('Average Rating by top 10 biggest brand')
axes[1].set(ylabel=None)


#display
plt.show()
# Out:
# <ipython-input-16-9af915f80fa9>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   axes[1] = sns.barplot(
# <ipython-input-16-9af915f80fa9>:22: UserWarning:
# The palette list has fewer values (6) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   axes[1] = sns.barplot(

# %% [markdown]
#    <a id="2"></a>
# <font color="tblue" size=+2.5><b>2. Data Cleaning</b></font>

# %% [markdown]
# <a id="2a"></a>
# <font color="black" size=+1.5><b>a. Replacing null values</b></font>

# %% [markdown]
# <a id="2ai"></a>
# <font color="black" size=+1><b>i. Brand Names</b></font>

# %%
df[df['Brand Name'].isnull()]
# Out:
#                                              Product Name Brand Name   Price  \
# 110     ((Unlocked))BlackBerry Bold 9650 Unlocked Clea...        NaN  269.10
# 111     ((Unlocked))BlackBerry Bold 9650 Unlocked Clea...        NaN  269.10
# 112     ((Unlocked))BlackBerry Bold 9650 Unlocked Clea...        NaN  269.10
# 113     ((Unlocked))BlackBerry Bold 9650 Unlocked Clea...        NaN  269.10
# 114     ((Unlocked))BlackBerry Bold 9650 Unlocked Clea...        NaN  269.10
# ...                                                   ...        ...     ...
# 413097  ZTE V987 Android 4.1 MT6589 Quad Core 1.2GHz D...        NaN  167.22
# 413098  ZTE V987 Android 4.1 MT6589 Quad Core 1.2GHz D...        NaN  167.22
# 413099  ZTE V987 Android 4.1 MT6589 Quad Core 1.2GHz D...        NaN  167.22
# 413100  ZTE V987 Android 4.1 MT6589 Quad Core 1.2GHz D...        NaN  167.22
# 413101  ZTE V987 Android 4.1 MT6589 Quad Core 1.2GHz D...        NaN  167.22
#
#         Rating                                            Reviews  \
# 110          2  when i got phone it wouldn't work I took it to...
# 111          4                                            I liked
# 112          5                            Great. Arrived quickly.
# 113          4  Phone works great, you may have to get a sum c...
# 114          5  Avianna LLC is an incredible seller. The phone...
# ...        ...                                                ...
# 413097       5                                          EXCELENTE
# 413098       2           Not as expected so I returned this phone
# 413099       5                                          very well
# 413100       5                                          excelente
# 413101       5                            great product! i loved!
#
#         Review Votes
# 110              0.0
# 111              0.0
# 112              0.0
# 113              0.0
# 114              0.0
# ...              ...
# 413097           0.0
# 413098           0.0
# 413099           0.0
# 413100           0.0
# 413101           0.0
#
# [65171 rows x 6 columns]

# %%
first_words = df['Product Name'].str.split().str[0]

# %%
df['Brand Name'].fillna(first_words, inplace=True)

# %%
brand_counts = df['Brand Name'].value_counts().sort_index()
print(brand_counts.head())
# Out:
# ((Unlocked))BlackBerry      8
# 2.45                        2
# 4                         158
# 4G                          2
# 4G-Unlocked                 7
# Name: Brand Name, dtype: int64

# %%
df['Brand Name'] = df['Brand Name'].replace({'BLACK': 'BLACKBERRY', 'Black Berry':'BLACKBERRY', 'BlackBerry':'BLACKBERRY', 'BlackBerry Storm 9530 Smartphone Unlocked GSM Wireless Handheld Device w/Camera Bluetooth 3.25" Touchscreen LCD':'BLACKBERRY','Blackberrry':'BLACKBERRY','Blackberry': 'BLACKBERRY'})
df['Brand Name'] = df['Brand Name'].replace({'((Unlocked))BlackBerry': 'BLACKBERRY'})
df['Brand Name'] = df['Brand Name'].replace({'Boost Mobile': 'Boost'})
df['Brand Name'] = df['Brand Name'].replace({'ASUS Computers': 'ASUS'})
df['Brand Name'] = df['Brand Name'].replace({'Asus': 'ASUS'})
df['Brand Name'] = df['Brand Name'].replace({'ATT': 'AT&T'})
df['Brand Name'] = df['Brand Name'].replace({'Amazon.com, LLC *** KEEP PORules ACTIVE ***': 'Amazon'})
df['Brand Name'] = df['Brand Name'].replace({'Apple Computer': 'Apple'})
df['Brand Name'] = df['Brand Name'].replace({'CBSKY®': 'CBSKY'})

# %% [markdown]
# <a id="2aii"></a>
# <font color="black" size=+1><b>ii. Reviews</b></font>

# %%
#add Review Length
df['Review Length'] = df['Reviews'].str.len()

# %%
df[df['Reviews'].isnull()]
# Out:
#                                              Product Name Brand Name   Price  \
# 6428    Apple Iphone 4 - 8gb Sprint (CDMA) White, Smar...      Apple     NaN
# 12533   Apple iPhone 4S 16GB 3G WiFi White Smartphone ...      Apple   74.95
# 13024   Apple iPhone 4S 16GB Unlocked GSM - White (Cer...      Apple  129.99
# 13533   Apple iPhone 4S 16GB Unlocked GSM - White (Cer...      Apple  129.99
# 14651   Apple iPhone 4S 32GB Unlocked GSM Smartphone w...      Apple     NaN
# ...                                                   ...        ...     ...
# 368836  Samsung Galaxy S6 SM-G920i Factory Unlocked Ce...    samsung  429.99
# 369106  Samsung Galaxy S6 SM-G920i Unlocked Cellphone,...    Samsung  479.99
# 369670  Samsung Galaxy S6 SM-G920i Unlocked Cellphone,...    Samsung  479.99
# 379690  Samsung N920 Unlocked Galaxy Note 5, GSM 32GB ...    Samsung  561.50
# 379977  Samsung N920 Unlocked Galaxy Note 5, GSM 32GB ...    Samsung  561.50
#
#         Rating Reviews  Review Votes  Review Length
# 6428         4     NaN           2.0            NaN
# 12533        1     NaN           0.0            NaN
# 13024        4     NaN           3.0            NaN
# 13533        5     NaN           2.0            NaN
# 14651        4     NaN           3.0            NaN
# ...        ...     ...           ...            ...
# 368836       4     NaN          48.0            NaN
# 369106       4     NaN          48.0            NaN
# 369670       4     NaN          48.0            NaN
# 379690       5     NaN           2.0            NaN
# 379977       5     NaN           2.0            NaN
#
# [62 rows x 7 columns]

# %%
df['Reviews'] = df['Reviews'].fillna("")
df['Review Length'] = df['Review Length'].fillna(0)

# %%
df[df['Reviews'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Product Name, Brand Name, Price, Rating, Reviews, Review Votes, Review Length]
# Index: []

# %% [markdown]
# ## **Price**

# %% [markdown]
# <a id="2a"></a>
# <font color="black" size=+1.5><b>a. Removing outliers </b></font>

# %%
df['Price'] = pd.to_numeric(df['Price'])

# %%
#remove items with price = 1.73
df = df[df['Price'] > 1.73]

# %%
df[df['Price'].notna() & (df['Price'] <= 79.99)].sort_values(by="Price")
# Out:
#                                              Product Name     Brand Name  \
# 83248   AT&T Wireless 3G / 4G / LTE Micro SIM Card - P...           AT&T
# 83236   AT&T Wireless 3G / 4G / LTE Micro SIM Card - P...           AT&T
# 83235   AT&T Wireless 3G / 4G / LTE Micro SIM Card - P...           AT&T
# 83234   AT&T Wireless 3G / 4G / LTE Micro SIM Card - P...           AT&T
# 83233   AT&T Wireless 3G / 4G / LTE Micro SIM Card - P...           AT&T
# ...                                                   ...            ...
# 177095  CNPGD MultiFunction All-in-1 Watch Cell Phone ...          CNPGD
# 177094  CNPGD MultiFunction All-in-1 Watch Cell Phone ...          CNPGD
# 177093  CNPGD MultiFunction All-in-1 Watch Cell Phone ...          CNPGD
# 177099  CNPGD MultiFunction All-in-1 Watch Cell Phone ...          CNPGD
# 388025  Sony Ericsson Xperia Ion 4G LT28a AT&T Android...  Sony Ericsson
#
#         Price  Rating                                            Reviews  \
# 83248    2.29       5  Bought from Tech Trend. Arrived on time, and i...
# 83236    2.29       5                               great item thank you
# 83235    2.29       5  Arrived right on time and the SIM worked perfe...
# 83234    2.29       5  New item in original packaging. It's a SIM car...
# 83233    2.29       5                                               Good
# ...       ...     ...                                                ...
# 177095  79.99       3  It's okay. The app is crap. I can't figure out...
# 177094  79.99       2                                              Nope.
# 177093  79.99       1  I wanted a cheap fitness tracker with clock.Th...
# 177099  79.99       2  It's used and there is some privete informatio...
# 388025  79.99       1  It has never worked. it does not detect the si...
#
#         Review Votes  Review Length
# 83248            0.0           54.0
# 83236            0.0           20.0
# 83235            0.0           74.0
# 83234            0.0           61.0
# 83233            0.0            4.0
# ...              ...            ...
# 177095           1.0          175.0
# 177094           0.0            5.0
# 177093           1.0          653.0
# 177099           0.0           78.0
# 388025           1.0          136.0
#
# [105217 rows x 7 columns]

# %%
df = df[df['Product Name'] != 'AT&T Wireless 3G / 4G / LTE Micro SIM Card - Postpaid /Go Phone Prepaid - SKU 4681B Softcard SIM']

# %%
df = df[df['Product Name']!='Unlock Alcatel Service']

# %%
df = df[df['Price'] > 10.99]

# %%
df.describe()
# Out:
#                Price         Rating   Review Votes  Review Length
# count  403593.000000  403593.000000  391528.000000  403593.000000
# mean      229.215833       3.824075       1.518022     217.402016
# std       273.509481       1.546439       9.232737     465.473035
# min        11.110000       1.000000       0.000000       0.000000
# 25%        79.990000       3.000000       0.000000      27.000000
# 50%       149.350000       5.000000       0.000000      94.000000
# 75%       274.860000       5.000000       1.000000     224.000000
# max      2598.000000       5.000000     645.000000   29419.000000

# %% [markdown]
# <a id="2b"></a>
# <font color="black" size=+1.5><b>b. Replacing Null values </b></font>

# %%
#create product_df with its average price
product_df = df[df['Price'].isnull() == False].groupby('Product Name').agg({'Price':'mean'})
product_df['Product Name'] = product_df.index
product_df.reset_index(drop=True, inplace=True)

product_df.head()

#iterrate through rows that has null price value in main df
#replace any null price value with existing price value that product_df
#replace any null price value that does not exist in product_df with total average price in the main df
for index, row in df[df['Price'].isnull()].iterrows():
  for index_2, row_2 in product_df.iterrows():
    if row['Product Name'] == row_2['Product Name']:
      row['Price'] = row_2['Price']
    else:
      row['Price'] = df['Price'].mean()

# %% [markdown]
#    <a id="3"></a>
# <font color="tblue" size=+2.5><b>3. Data Visualization</b></font>

# %%
#em lam trong Tableau cho nhanh nha
#oke em

# %% [markdown]
#    <a id="4"></a>
# <font color="tblue" size=+2.5><b>4. Data Export</b></font>

# %%
df.to_csv('df1.csv', index=False)

# %% [markdown]
# <a id="5"></a>
# <font color="tblue" size=+2.5><b>5. Sentiment Analysis</b></font>

# %%
#!pip install nltk

import nltk

from nltk.tokenize import word_tokenize

from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = ""

for review in df['Reviews']:
  text = text + review

print(len(text))
# Out:
# 87741932

# %%
# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
